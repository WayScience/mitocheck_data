# %% [markdown]
# ### Import libraries

# %%
import pathlib
import pandas as pd
import numpy as np

import sys
sys.path.append("../utils")
from load_utils import compile_mitocheck_batch_data
from training_data_utils import get_labeled_cells

# %% [markdown]
# ## Set save directory

# %%
results_dir = pathlib.Path("results/")
results_dir.mkdir(exist_ok=True, parents=True)

# %% [markdown]
# ## Compile, Format, Save Training Data

# %%
dataset_types = ["ic", "no_ic"]

for dataset_type in dataset_types:
    print(f"Compiling data for dataset type {dataset_type}")

    # Load training data
    training_data_features_path = pathlib.Path(f"../1.idr_streams/extracted_features/training_data__{dataset_type}/merged_features/")
    training_data = compile_mitocheck_batch_data(training_data_features_path)
    print(f"Training data has {training_data.shape}")
    
    # Find cells with MitoCheck data
    # Cells may not have feature data found because the specific well is not hosted on IDr (failure to pass QC) or because of differences in Mitocheck/DeepProfiler segmentation
    features_samples_path = pathlib.Path("../mitocheck_metadata/features.samples.txt")
    training_cells = get_labeled_cells(training_data, features_samples_path, "DP__Object_Outline")
    print(f"Shape of labeled_cells: {training_cells.shape}")
    
    # Replace `Shape1` and `Shape3` with their respective classes
    # See https://github.com/WayScience/mitocheck_data/issues/16 for more details
    training_cells = training_cells.replace("Shape1", "Binuclear")
    training_cells = training_cells.replace("Shape3", "Polylobed")
    
    # Save compiled training data
    compiled_training_data_path = pathlib.Path(f"{results_dir}/training_data__{dataset_type}.csv.gz")
    training_cells.to_csv(compiled_training_data_path, compression="gzip")
# Out:
# Compiling data for dataset type ic
# Loading data from ../1.idr_streams/extracted_features/training_data__ic/merged_features...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_23.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_2.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_26.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_6.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_9.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_27.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_0.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_14.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_5.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_24.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_19.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_10.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_21.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_22.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_17.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_16.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_7.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_13.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_15.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_1.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_3.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_8.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_4.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_18.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_12.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_25.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_20.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__ic/merged_features/batch_11.csv.gz...
# Training data has (64513, 1449)
# No feature data derived for cell at: LT0100_03, 93, 84, 241, 710
# No feature data derived for cell at: LT0014_12, 159, 70, 911, 678
# No feature data derived for cell at: LT0043_48, 166, 44, 296, 320
# No feature data derived for cell at: LT0043_48, 166, 71, 279, 313
# No feature data derived for cell at: LT0066_19, 287, 48, 1137, 693
# No feature data derived for cell at: LT0066_19, 287, 48, 773, 103
# No feature data derived for cell at: LT0066_19, 287, 48, 471, 480
# No feature data derived for cell at: LT0066_19, 287, 75, 300, 522
# No feature data derived for cell at: LT0066_19, 287, 75, 701, 156
# No feature data derived for cell at: LT0066_19, 287, 75, 1029, 548
# No feature data derived for cell at: LT0066_19, 287, 75, 1138, 689
# No feature data derived for cell at: LT0066_19, 287, 75, 470, 779
# No feature data derived for cell at: LT0066_19, 287, 75, 958, 105
# No feature data derived for cell at: LT0066_19, 287, 75, 719, 347
# No feature data derived for cell at: LT0066_19, 287, 87, 826, 373
# No feature data derived for cell at: LT0066_19, 287, 87, 1229, 384
# No feature data derived for cell at: LT0066_19, 287, 87, 587, 445
# No feature data derived for cell at: LT0066_19, 287, 87, 719, 345
# No feature data derived for cell at: LT0066_19, 287, 93, 668, 25
# No feature data derived for cell at: LT0066_19, 287, 93, 517, 292
# No feature data derived for cell at: LT0084_46, 3, 56, 1242, 633
# No feature data derived for cell at: LT0091_30, 169, 43, 1243, 869
# No feature data derived for cell at: LT0091_30, 169, 43, 787, 603
# No feature data derived for cell at: LT0157_04, 5, 47, 1278, 951
# No feature data derived for cell at: LT0157_04, 5, 61, 373, 912
# No feature data derived for cell at: LT0157_04, 5, 78, 833, 423
# No feature data derived for cell at: LT0003_40, 149, 83, 943, 381
# No feature data derived for cell at: LT0013_42, 107, 28, 208, 555
# No feature data derived for cell at: LT0015_22, 69, 89, 1248, 921
# No feature data derived for cell at: LT0015_22, 69, 89, 686, 367
# No feature data derived for cell at: LT0019_06, 140, 70, 423, 374
# No feature data derived for cell at: LT0019_06, 140, 83, 965, 580
# No feature data derived for cell at: LT0026_22, 258, 67, 1010, 442
# No feature data derived for cell at: LT0039_45, 281, 26, 988, 298
# No feature data derived for cell at: LT0039_45, 281, 27, 989, 308
# No feature data derived for cell at: LT0041_32, 132, 74, 904, 154
# No feature data derived for cell at: LT0048_14, 335, 29, 726, 693
# No feature data derived for cell at: LT0048_14, 335, 29, 941, 166
# No feature data derived for cell at: LT0048_14, 335, 29, 476, 547
# No feature data derived for cell at: LT0048_14, 335, 56, 545, 837
# No feature data derived for cell at: LT0048_14, 335, 56, 466, 558
# No feature data derived for cell at: LT0048_14, 335, 56, 193, 423
# No feature data derived for cell at: LT0048_14, 335, 56, 483, 557
# No feature data derived for cell at: LT0064_14, 3, 54, 268, 514
# No feature data derived for cell at: LT0066_19, 287, 22, 1206, 673
# No feature data derived for cell at: LT0066_19, 287, 48, 1104, 456
# No feature data derived for cell at: LT0066_19, 287, 75, 1101, 460
# No feature data derived for cell at: LT0066_19, 287, 87, 817, 552
# No feature data derived for cell at: LT0066_19, 287, 87, 404, 517
# No feature data derived for cell at: LT0089_01, 175, 93, 223, 611
# No feature data derived for cell at: LT0089_01, 175, 93, 505, 363
# No feature data derived for cell at: LT0090_33, 383, 84, 399, 298
# No feature data derived for cell at: LT0094_01, 319, 85, 507, 685
# No feature data derived for cell at: LT0094_01, 319, 85, 282, 416
# No feature data derived for cell at: LT0094_01, 319, 85, 215, 445
# No feature data derived for cell at: LT0109_38, 381, 87, 874, 321
# No feature data derived for cell at: LT0109_38, 381, 87, 762, 636
# No feature data derived for cell at: LT0109_38, 338, 80, 965, 563
# No feature data derived for cell at: LT0138_03, 127, 51, 536, 844
# No feature data derived for cell at: LT0138_03, 127, 51, 639, 666
# No feature data derived for cell at: LT0138_03, 127, 51, 136, 626
# No feature data derived for cell at: LT0023_04, 5, 30, 1119, 887
# No feature data derived for cell at: LT0090_33, 383, 84, 669, 392
# No feature data derived for cell at: LT0090_33, 383, 92, 625, 387
# No feature data derived for cell at: LT0100_03, 93, 37, 1047, 249
# No feature data derived for cell at: LT0094_04, 319, 5, 749, 835
# No feature data derived for cell at: LT0094_04, 319, 7, 749, 834
# No feature data derived for cell at: LT0138_03, 127, 30, 815, 694
# No feature data derived for cell at: LT0138_03, 127, 35, 706, 818
# No feature data derived for cell at: LT0030_17, 184, 39, 1101, 533
# No feature data derived for cell at: LT0003_40, 149, 83, 407, 878
# No feature data derived for cell at: LT0012_25, 349, 83, 106, 565
# No feature data derived for cell at: LT0012_25, 349, 83, 1085, 631
# No feature data derived for cell at: LT0012_29, 252, 83, 631, 846
# No feature data derived for cell at: LT0013_38, 42, 47, 1158, 821
# No feature data derived for cell at: LT0013_38, 42, 75, 1136, 849
# No feature data derived for cell at: LT0013_38, 42, 75, 387, 171
# No feature data derived for cell at: LT0013_38, 42, 75, 79, 176
# No feature data derived for cell at: LT0013_38, 42, 75, 294, 485
# No feature data derived for cell at: LT0013_38, 42, 75, 341, 501
# No feature data derived for cell at: LT0013_38, 42, 75, 1258, 381
# No feature data derived for cell at: LT0013_38, 42, 75, 818, 594
# No feature data derived for cell at: LT0013_38, 42, 95, 735, 93
# No feature data derived for cell at: LT0013_38, 42, 95, 1261, 364
# No feature data derived for cell at: LT0013_42, 107, 76, 1053, 573
# No feature data derived for cell at: LT0013_42, 107, 76, 1312, 216
# No feature data derived for cell at: LT0013_42, 107, 76, 278, 715
# No feature data derived for cell at: LT0013_42, 107, 76, 607, 242
# No feature data derived for cell at: LT0014_12, 159, 70, 1265, 866
# No feature data derived for cell at: LT0017_19, 365, 83, 734, 253
# No feature data derived for cell at: LT0017_19, 365, 83, 767, 833
# No feature data derived for cell at: LT0017_19, 365, 93, 744, 259
# No feature data derived for cell at: LT0017_19, 365, 93, 797, 133
# No feature data derived for cell at: LT0017_19, 365, 93, 783, 940
# No feature data derived for cell at: LT0017_19, 365, 93, 868, 195
# No feature data derived for cell at: LT0019_06, 140, 70, 361, 879
# No feature data derived for cell at: LT0023_04, 5, 64, 696, 482
# No feature data derived for cell at: LT0023_04, 5, 72, 563, 675
# No feature data derived for cell at: LT0023_04, 5, 87, 892, 597
# No feature data derived for cell at: LT0026_22, 258, 67, 1050, 779
# No feature data derived for cell at: LT0026_22, 258, 85, 870, 710
# No feature data derived for cell at: LT0027_44, 292, 88, 406, 102
# No feature data derived for cell at: LT0027_44, 30, 58, 799, 349
# No feature data derived for cell at: LT0027_44, 30, 58, 838, 162
# No feature data derived for cell at: LT0027_44, 30, 58, 205, 586
# No feature data derived for cell at: LT0027_44, 30, 74, 213, 627
# No feature data derived for cell at: LT0027_44, 30, 74, 802, 388
# No feature data derived for cell at: LT0027_44, 30, 86, 958, 286
# No feature data derived for cell at: LT0027_44, 30, 86, 82, 954
# No feature data derived for cell at: LT0027_44, 30, 86, 733, 690
# No feature data derived for cell at: LT0027_44, 30, 86, 200, 654
# No feature data derived for cell at: LT0027_44, 30, 86, 686, 601
# No feature data derived for cell at: LT0027_44, 30, 86, 232, 234
# No feature data derived for cell at: LT0027_44, 30, 86, 869, 391
# No feature data derived for cell at: LT0027_44, 30, 95, 897, 400
# No feature data derived for cell at: LT0027_44, 30, 95, 202, 657
# No feature data derived for cell at: LT0027_44, 30, 95, 735, 692
# No feature data derived for cell at: LT0027_44, 30, 95, 254, 431
# No feature data derived for cell at: LT0027_44, 30, 95, 755, 178
# No feature data derived for cell at: LT0027_44, 30, 95, 696, 601
# No feature data derived for cell at: LT0028_14, 129, 55, 676, 259
# No feature data derived for cell at: LT0028_14, 129, 66, 670, 251
# No feature data derived for cell at: LT0028_14, 129, 66, 712, 139
# No feature data derived for cell at: LT0042_10, 144, 88, 224, 890
# No feature data derived for cell at: LT0043_48, 166, 47, 276, 266
# No feature data derived for cell at: LT0043_48, 166, 55, 656, 255
# No feature data derived for cell at: LT0043_48, 166, 56, 288, 310
# No feature data derived for cell at: LT0043_48, 166, 79, 475, 338
# No feature data derived for cell at: LT0043_48, 166, 79, 71, 678
# No feature data derived for cell at: LT0043_48, 166, 84, 472, 604
# No feature data derived for cell at: LT0043_48, 166, 84, 793, 745
# No feature data derived for cell at: LT0044_36, 249, 46, 146, 247
# No feature data derived for cell at: LT0046_19, 356, 92, 485, 196
# No feature data derived for cell at: LT0047_27, 140, 84, 132, 794
# No feature data derived for cell at: LT0065_04, 20, 57, 787, 473
# No feature data derived for cell at: LT0065_04, 20, 72, 860, 190
# No feature data derived for cell at: LT0065_04, 20, 92, 1017, 824
# No feature data derived for cell at: LT0065_04, 20, 92, 765, 494
# No feature data derived for cell at: LT0065_06, 54, 93, 1002, 157
# No feature data derived for cell at: LT0067_02, 99, 77, 1147, 405
# No feature data derived for cell at: LT0067_02, 99, 77, 604, 686
# No feature data derived for cell at: LT0067_02, 99, 92, 602, 690
# No feature data derived for cell at: LT0084_46, 3, 46, 982, 454
# No feature data derived for cell at: LT0084_46, 3, 56, 783, 770
# No feature data derived for cell at: LT0084_46, 3, 56, 1015, 858
# No feature data derived for cell at: LT0084_46, 3, 56, 99, 390
# No feature data derived for cell at: LT0084_46, 3, 80, 151, 247
# No feature data derived for cell at: LT0084_46, 3, 80, 183, 320
# No feature data derived for cell at: LT0084_46, 3, 91, 379, 137
# No feature data derived for cell at: LT0084_46, 3, 91, 1006, 354
# No feature data derived for cell at: LT0084_46, 3, 91, 160, 144
# No feature data derived for cell at: LT0084_46, 3, 91, 789, 639
# No feature data derived for cell at: LT0089_01, 175, 39, 1133, 894
# No feature data derived for cell at: LT0089_01, 175, 44, 339, 34
# No feature data derived for cell at: LT0089_01, 175, 60, 772, 880
# No feature data derived for cell at: LT0089_01, 175, 71, 763, 875
# No feature data derived for cell at: LT0089_01, 175, 71, 393, 574
# No feature data derived for cell at: LT0089_01, 175, 93, 164, 438
# No feature data derived for cell at: LT0089_01, 175, 93, 1027, 766
# No feature data derived for cell at: LT0093_13, 147, 69, 290, 228
# No feature data derived for cell at: LT0093_17, 114, 88, 747, 391
# No feature data derived for cell at: LT0093_17, 114, 88, 137, 718
# No feature data derived for cell at: LT0094_04, 319, 66, 1088, 939
# No feature data derived for cell at: LT0098_13, 21, 21, 224, 50
# No feature data derived for cell at: LT0098_13, 21, 27, 627, 377
# No feature data derived for cell at: LT0098_13, 21, 77, 379, 655
# No feature data derived for cell at: LT0100_03, 93, 37, 581, 212
# No feature data derived for cell at: LT0100_03, 93, 37, 1311, 693
# No feature data derived for cell at: LT0100_03, 93, 56, 118, 521
# No feature data derived for cell at: LT0100_03, 93, 84, 1034, 629
# No feature data derived for cell at: LT0132_31, 53, 75, 498, 160
# No feature data derived for cell at: LT0132_31, 53, 75, 183, 217
# No feature data derived for cell at: LT0157_04, 5, 61, 515, 291
# No feature data derived for cell at: LT0157_04, 5, 78, 938, 351
# No feature data derived for cell at: LT0602_04, 59, 49, 363, 951
# No feature data derived for cell at: LT0602_04, 59, 49, 318, 907
# No feature data derived for cell at: LT0013_38, 42, 47, 1115, 361
# No feature data derived for cell at: LT0013_38, 42, 47, 987, 204
# No feature data derived for cell at: LT0013_38, 42, 47, 586, 882
# No feature data derived for cell at: LT0013_38, 42, 47, 326, 104
# No feature data derived for cell at: LT0013_38, 42, 47, 582, 299
# No feature data derived for cell at: LT0013_38, 42, 47, 262, 879
# No feature data derived for cell at: LT0013_38, 42, 75, 1156, 191
# No feature data derived for cell at: LT0013_38, 42, 75, 1239, 258
# No feature data derived for cell at: LT0013_38, 42, 75, 390, 417
# No feature data derived for cell at: LT0013_38, 42, 75, 208, 400
# No feature data derived for cell at: LT0013_38, 42, 75, 1296, 879
# No feature data derived for cell at: LT0013_38, 42, 75, 144, 367
# No feature data derived for cell at: LT0013_38, 42, 95, 1180, 341
# No feature data derived for cell at: LT0013_38, 42, 95, 188, 407
# No feature data derived for cell at: LT0013_38, 42, 95, 922, 158
# No feature data derived for cell at: LT0013_38, 42, 95, 260, 380
# No feature data derived for cell at: LT0013_38, 42, 95, 697, 980
# No feature data derived for cell at: LT0013_42, 107, 23, 407, 590
# No feature data derived for cell at: LT0013_42, 107, 28, 177, 764
# No feature data derived for cell at: LT0013_42, 107, 28, 111, 995
# No feature data derived for cell at: LT0013_42, 107, 52, 73, 295
# No feature data derived for cell at: LT0013_42, 107, 52, 410, 588
# No feature data derived for cell at: LT0013_42, 107, 52, 283, 77
# No feature data derived for cell at: LT0013_42, 107, 76, 1271, 473
# No feature data derived for cell at: LT0017_19, 365, 65, 1048, 464
# No feature data derived for cell at: LT0017_19, 365, 65, 197, 470
# No feature data derived for cell at: LT0017_19, 365, 65, 129, 355
# No feature data derived for cell at: LT0017_19, 365, 65, 712, 139
# No feature data derived for cell at: LT0017_19, 365, 65, 593, 53
# No feature data derived for cell at: LT0017_19, 365, 65, 494, 732
# No feature data derived for cell at: LT0017_19, 365, 65, 666, 356
# No feature data derived for cell at: LT0017_19, 365, 83, 588, 44
# No feature data derived for cell at: LT0017_19, 365, 83, 122, 490
# No feature data derived for cell at: LT0017_19, 365, 83, 718, 123
# No feature data derived for cell at: LT0017_19, 365, 83, 188, 748
# No feature data derived for cell at: LT0017_19, 365, 93, 586, 44
# No feature data derived for cell at: LT0023_04, 5, 30, 664, 319
# No feature data derived for cell at: LT0023_04, 5, 30, 713, 483
# No feature data derived for cell at: LT0023_04, 5, 30, 73, 235
# No feature data derived for cell at: LT0023_04, 5, 87, 844, 949
# No feature data derived for cell at: LT0023_04, 5, 87, 525, 981
# No feature data derived for cell at: LT0026_22, 258, 37, 486, 939
# No feature data derived for cell at: LT0026_22, 258, 37, 520, 757
# No feature data derived for cell at: LT0026_22, 258, 37, 621, 295
# No feature data derived for cell at: LT0026_22, 258, 37, 1074, 595
# No feature data derived for cell at: LT0026_22, 258, 37, 891, 391
# No feature data derived for cell at: LT0026_22, 258, 37, 877, 522
# No feature data derived for cell at: LT0026_22, 258, 67, 1105, 728
# No feature data derived for cell at: LT0026_22, 258, 67, 620, 300
# No feature data derived for cell at: LT0026_22, 258, 85, 942, 669
# No feature data derived for cell at: LT0026_22, 258, 85, 665, 476
# No feature data derived for cell at: LT0026_22, 258, 95, 658, 470
# No feature data derived for cell at: LT0026_22, 258, 95, 939, 674
# No feature data derived for cell at: LT0026_22, 258, 95, 751, 491
# No feature data derived for cell at: LT0026_22, 258, 95, 995, 695
# No feature data derived for cell at: LT0026_22, 258, 95, 494, 914
# No feature data derived for cell at: LT0027_44, 30, 58, 253, 234
# No feature data derived for cell at: LT0027_44, 30, 58, 1205, 809
# No feature data derived for cell at: LT0027_44, 30, 95, 248, 191
# No feature data derived for cell at: LT0028_14, 129, 17, 1134, 426
# No feature data derived for cell at: LT0028_14, 129, 55, 705, 97
# No feature data derived for cell at: LT0028_14, 129, 66, 1103, 458
# No feature data derived for cell at: LT0028_14, 129, 66, 566, 388
# No feature data derived for cell at: LT0028_14, 129, 66, 1321, 323
# No feature data derived for cell at: LT0028_14, 129, 66, 1210, 189
# No feature data derived for cell at: LT0028_14, 129, 91, 1170, 825
# No feature data derived for cell at: LT0028_14, 129, 91, 914, 666
# No feature data derived for cell at: LT0028_14, 129, 91, 585, 271
# No feature data derived for cell at: LT0028_14, 129, 91, 789, 144
# No feature data derived for cell at: LT0028_14, 129, 91, 594, 333
# No feature data derived for cell at: LT0028_14, 129, 91, 1059, 96
# No feature data derived for cell at: LT0028_14, 129, 91, 1132, 777
# No feature data derived for cell at: LT0038_27, 250, 8, 291, 799
# No feature data derived for cell at: LT0043_48, 166, 36, 61, 667
# No feature data derived for cell at: LT0043_48, 166, 36, 498, 593
# No feature data derived for cell at: LT0043_48, 166, 36, 822, 721
# No feature data derived for cell at: LT0043_48, 166, 44, 68, 188
# No feature data derived for cell at: LT0043_48, 166, 55, 997, 510
# No feature data derived for cell at: LT0046_19, 356, 57, 351, 64
# No feature data derived for cell at: LT0046_19, 356, 57, 676, 451
# No feature data derived for cell at: LT0046_19, 356, 57, 628, 513
# No feature data derived for cell at: LT0046_19, 356, 57, 63, 397
# No feature data derived for cell at: LT0046_19, 356, 57, 625, 109
# No feature data derived for cell at: LT0046_19, 356, 57, 533, 82
# No feature data derived for cell at: LT0046_19, 356, 67, 627, 435
# No feature data derived for cell at: LT0046_19, 356, 67, 772, 433
# No feature data derived for cell at: LT0046_19, 356, 67, 1089, 427
# No feature data derived for cell at: LT0046_19, 356, 67, 674, 449
# No feature data derived for cell at: LT0046_19, 356, 67, 622, 511
# No feature data derived for cell at: LT0046_19, 356, 67, 807, 190
# No feature data derived for cell at: LT0046_19, 356, 67, 298, 497
# No feature data derived for cell at: LT0046_19, 356, 67, 353, 66
# No feature data derived for cell at: LT0047_27, 140, 68, 115, 855
# No feature data derived for cell at: LT0047_27, 140, 75, 558, 400
# No feature data derived for cell at: LT0048_13, 69, 15, 337, 738
# No feature data derived for cell at: LT0065_04, 20, 49, 226, 289
# No feature data derived for cell at: LT0065_04, 20, 49, 579, 875
# No feature data derived for cell at: LT0065_04, 20, 57, 581, 873
# No feature data derived for cell at: LT0065_04, 20, 57, 1006, 788
# No feature data derived for cell at: LT0065_04, 20, 72, 300, 559
# No feature data derived for cell at: LT0065_04, 20, 72, 544, 875
# No feature data derived for cell at: LT0067_02, 99, 19, 549, 770
# No feature data derived for cell at: LT0067_02, 99, 19, 592, 415
# No feature data derived for cell at: LT0067_02, 99, 19, 292, 978
# No feature data derived for cell at: LT0067_02, 99, 19, 1148, 815
# No feature data derived for cell at: LT0067_02, 99, 37, 132, 568
# No feature data derived for cell at: LT0067_02, 99, 37, 64, 818
# No feature data derived for cell at: LT0067_02, 99, 37, 264, 947
# No feature data derived for cell at: LT0067_02, 99, 37, 24, 809
# No feature data derived for cell at: LT0067_02, 99, 37, 1130, 388
# No feature data derived for cell at: LT0067_02, 99, 37, 1148, 869
# No feature data derived for cell at: LT0067_02, 99, 37, 722, 996
# No feature data derived for cell at: LT0067_02, 99, 37, 549, 746
# No feature data derived for cell at: LT0067_02, 99, 37, 207, 147
# No feature data derived for cell at: LT0067_02, 99, 37, 1159, 553
# No feature data derived for cell at: LT0067_02, 99, 37, 37, 635
# No feature data derived for cell at: LT0067_02, 99, 37, 1265, 185
# No feature data derived for cell at: LT0067_02, 99, 37, 1148, 818
# No feature data derived for cell at: LT0067_02, 99, 37, 739, 211
# No feature data derived for cell at: LT0067_02, 99, 37, 741, 802
# No feature data derived for cell at: LT0084_46, 3, 46, 1072, 823
# No feature data derived for cell at: LT0084_46, 3, 46, 694, 727
# No feature data derived for cell at: LT0084_46, 3, 46, 1004, 830
# No feature data derived for cell at: LT0084_46, 3, 46, 110, 121
# No feature data derived for cell at: LT0089_01, 175, 44, 1227, 348
# No feature data derived for cell at: LT0093_13, 147, 77, 741, 917
# No feature data derived for cell at: LT0093_13, 147, 77, 929, 123
# No feature data derived for cell at: LT0093_13, 147, 77, 842, 980
# No feature data derived for cell at: LT0100_03, 93, 37, 198, 140
# No feature data derived for cell at: LT0100_03, 93, 56, 1078, 704
# No feature data derived for cell at: LT0100_03, 93, 56, 133, 315
# No feature data derived for cell at: LT0100_03, 93, 84, 144, 711
# No feature data derived for cell at: LT0109_38, 381, 66, 774, 765
# No feature data derived for cell at: LT0109_38, 349, 88, 1292, 961
# No feature data derived for cell at: LT0157_04, 5, 61, 858, 953
# No feature data derived for cell at: LT0602_04, 59, 49, 846, 491
# No feature data derived for cell at: LT0602_04, 59, 49, 900, 448
# No feature data derived for cell at: LT0602_04, 59, 49, 245, 858
# No feature data derived for cell at: LT0602_04, 59, 49, 464, 938
# No feature data derived for cell at: LT0602_04, 59, 49, 100, 778
# No feature data derived for cell at: LT0602_04, 59, 49, 834, 390
# No feature data derived for cell at: LT0602_04, 59, 49, 344, 170
# No feature data derived for cell at: LT0602_04, 59, 49, 514, 256
# No feature data derived for cell at: LT0602_04, 59, 49, 379, 800
# No feature data derived for cell at: LT0602_04, 59, 49, 903, 89
# No feature data derived for cell at: LT0602_04, 59, 49, 87, 882
# No feature data derived for cell at: LT0602_04, 59, 49, 626, 408
# No feature data derived for cell at: LT0602_04, 59, 49, 442, 426
# No feature data derived for cell at: LT0602_04, 59, 49, 68, 496
# No feature data derived for cell at: LT0602_04, 59, 49, 568, 130
# No feature data derived for cell at: LT0602_04, 59, 49, 478, 891
# No feature data derived for cell at: LT0602_04, 59, 49, 437, 602
# No feature data derived for cell at: LT0602_04, 59, 49, 827, 284
# No feature data derived for cell at: LT0602_04, 59, 49, 385, 179
# No feature data derived for cell at: LT0602_04, 59, 49, 476, 783
# No feature data derived for cell at: LT0602_04, 59, 49, 670, 688
# No feature data derived for cell at: LT0602_04, 59, 49, 691, 770
# No feature data derived for cell at: LT0602_04, 59, 49, 146, 931
# No feature data derived for cell at: LT0602_04, 59, 49, 631, 734
# No feature data derived for cell at: LT0602_04, 59, 49, 96, 538
# No feature data derived for cell at: LT0602_04, 59, 49, 731, 637
# No feature data derived for cell at: LT0602_04, 59, 49, 168, 747
# No feature data derived for cell at: LT0043_48, 166, 36, 1207, 8
# No feature data derived for cell at: LT0026_22, 199, 13, 1154, 305
# No feature data derived for cell at: LT0027_45, 48, 13, 1228, 1006
# No feature data derived for cell at: LT0027_45, 48, 13, 894, 465
# No feature data derived for cell at: LT0027_45, 48, 13, 1147, 864
# No feature data derived for cell at: LT0027_45, 48, 13, 937, 757
# No feature data derived for cell at: LT0027_45, 48, 13, 850, 29
# No feature data derived for cell at: LT0027_45, 48, 13, 1016, 363
# No feature data derived for cell at: LT0027_45, 84, 13, 553, 905
# No feature data derived for cell at: LT0027_45, 84, 13, 528, 849
# No feature data derived for cell at: LT0027_45, 84, 13, 664, 216
# No feature data derived for cell at: LT0029_05, 60, 33, 553, 540
# No feature data derived for cell at: LT0029_05, 60, 33, 1028, 355
# No feature data derived for cell at: LT0029_05, 60, 33, 1071, 239
# No feature data derived for cell at: LT0029_05, 60, 33, 284, 232
# No feature data derived for cell at: LT0029_05, 60, 33, 284, 402
# No feature data derived for cell at: LT0029_05, 60, 33, 1109, 469
# No feature data derived for cell at: LT0078_05, 4, 33, 406, 988
# No feature data derived for cell at: LT0153_01, 13, 81, 1059, 539
# No feature data derived for cell at: LT0153_01, 13, 81, 363, 454
# No feature data derived for cell at: LT0153_01, 13, 81, 603, 656
# No feature data derived for cell at: LT0153_01, 13, 81, 627, 429
# No feature data derived for cell at: LT0601_01, 217, 49, 466, 216
# Shape of labeled_cells: (2916, 1450)
# Compiling data for dataset type no_ic
# Loading data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_23.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_2.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_26.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_6.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_9.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_27.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_0.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_14.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_5.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_24.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_19.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_10.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_21.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_22.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_17.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_16.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_7.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_13.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_15.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_1.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_3.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_8.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_4.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_18.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_12.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_25.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_20.csv.gz...
# Loading batch data from ../1.idr_streams/extracted_features/training_data__no_ic/merged_features/batch_11.csv.gz...
# Training data has (67769, 1449)
# No feature data derived for cell at: LT0043_48, 166, 44, 1011, 156
# No feature data derived for cell at: LT0043_48, 166, 52, 1068, 97
# No feature data derived for cell at: LT0048_13, 69, 72, 258, 60
# No feature data derived for cell at: LT0014_12, 159, 70, 911, 678
# No feature data derived for cell at: LT0043_48, 166, 44, 296, 320
# No feature data derived for cell at: LT0043_48, 166, 71, 279, 313
# No feature data derived for cell at: LT0066_19, 287, 48, 1137, 693
# No feature data derived for cell at: LT0066_19, 287, 48, 773, 103
# No feature data derived for cell at: LT0066_19, 287, 75, 1029, 548
# No feature data derived for cell at: LT0066_19, 287, 75, 958, 105
# No feature data derived for cell at: LT0066_19, 287, 75, 1132, 429
# No feature data derived for cell at: LT0066_19, 287, 75, 719, 347
# No feature data derived for cell at: LT0066_19, 287, 87, 826, 373
# No feature data derived for cell at: LT0066_19, 287, 87, 1229, 384
# No feature data derived for cell at: LT0066_19, 287, 87, 587, 445
# No feature data derived for cell at: LT0066_19, 287, 87, 719, 345
# No feature data derived for cell at: LT0066_19, 287, 93, 668, 25
# No feature data derived for cell at: LT0066_19, 287, 93, 517, 292
# No feature data derived for cell at: LT0084_46, 3, 56, 1242, 633
# No feature data derived for cell at: LT0084_46, 3, 56, 136, 170
# No feature data derived for cell at: LT0091_30, 169, 43, 1243, 869
# No feature data derived for cell at: LT0091_30, 169, 43, 787, 603
# No feature data derived for cell at: LT0157_04, 5, 47, 1278, 951
# No feature data derived for cell at: LT0157_04, 5, 61, 373, 912
# No feature data derived for cell at: LT0043_48, 166, 55, 579, 335
# No feature data derived for cell at: LT0003_40, 149, 83, 943, 381
# No feature data derived for cell at: LT0013_42, 107, 28, 208, 555
# No feature data derived for cell at: LT0013_42, 107, 39, 402, 797
# No feature data derived for cell at: LT0015_22, 69, 89, 1248, 921
# No feature data derived for cell at: LT0015_22, 69, 89, 686, 367
# No feature data derived for cell at: LT0019_06, 140, 70, 423, 374
# No feature data derived for cell at: LT0019_06, 140, 83, 965, 580
# No feature data derived for cell at: LT0039_45, 281, 26, 988, 298
# No feature data derived for cell at: LT0039_45, 281, 27, 989, 308
# No feature data derived for cell at: LT0039_45, 281, 29, 710, 812
# No feature data derived for cell at: LT0039_45, 281, 32, 611, 940
# No feature data derived for cell at: LT0039_45, 281, 32, 439, 386
# No feature data derived for cell at: LT0041_32, 132, 74, 904, 154
# No feature data derived for cell at: LT0048_14, 335, 29, 726, 693
# No feature data derived for cell at: LT0048_14, 335, 29, 941, 166
# No feature data derived for cell at: LT0048_14, 335, 56, 466, 558
# No feature data derived for cell at: LT0064_14, 3, 54, 268, 514
# No feature data derived for cell at: LT0066_19, 287, 22, 1206, 673
# No feature data derived for cell at: LT0066_19, 287, 75, 1101, 460
# No feature data derived for cell at: LT0066_19, 287, 87, 817, 552
# No feature data derived for cell at: LT0066_19, 287, 87, 404, 517
# No feature data derived for cell at: LT0089_01, 175, 93, 415, 592
# No feature data derived for cell at: LT0090_33, 383, 84, 399, 298
# No feature data derived for cell at: LT0091_30, 169, 21, 381, 675
# No feature data derived for cell at: LT0094_01, 319, 85, 507, 685
# No feature data derived for cell at: LT0094_01, 319, 85, 282, 416
# No feature data derived for cell at: LT0094_01, 319, 85, 215, 445
# No feature data derived for cell at: LT0109_38, 381, 87, 874, 321
# No feature data derived for cell at: LT0109_38, 381, 87, 762, 636
# No feature data derived for cell at: LT0109_38, 338, 80, 893, 393
# No feature data derived for cell at: LT0109_38, 338, 80, 965, 563
# No feature data derived for cell at: LT0138_03, 127, 51, 536, 844
# No feature data derived for cell at: LT0017_19, 365, 65, 746, 848
# No feature data derived for cell at: LT0023_04, 5, 30, 1119, 887
# No feature data derived for cell at: LT0030_17, 184, 87, 494, 258
# No feature data derived for cell at: LT0030_17, 184, 87, 87, 722
# No feature data derived for cell at: LT0043_48, 166, 57, 790, 737
# No feature data derived for cell at: LT0090_33, 383, 84, 489, 345
# No feature data derived for cell at: LT0090_33, 383, 84, 567, 319
# No feature data derived for cell at: LT0090_33, 383, 84, 669, 392
# No feature data derived for cell at: LT0090_33, 383, 92, 625, 387
# No feature data derived for cell at: LT0100_03, 93, 37, 1047, 249
# No feature data derived for cell at: LT0030_17, 58, 52, 588, 746
# No feature data derived for cell at: LT0094_04, 319, 5, 749, 835
# No feature data derived for cell at: LT0094_04, 319, 7, 749, 834
# No feature data derived for cell at: LT0138_03, 127, 30, 815, 694
# No feature data derived for cell at: LT0138_03, 127, 35, 706, 818
# No feature data derived for cell at: LT0030_17, 184, 39, 1101, 533
# No feature data derived for cell at: LT0003_40, 149, 83, 407, 878
# No feature data derived for cell at: LT0012_25, 349, 83, 1085, 631
# No feature data derived for cell at: LT0012_29, 252, 83, 631, 846
# No feature data derived for cell at: LT0012_29, 252, 83, 1006, 921
# No feature data derived for cell at: LT0013_38, 42, 47, 1158, 821
# No feature data derived for cell at: LT0013_38, 42, 75, 1136, 849
# No feature data derived for cell at: LT0013_38, 42, 75, 387, 171
# No feature data derived for cell at: LT0013_38, 42, 75, 79, 176
# No feature data derived for cell at: LT0013_38, 42, 75, 341, 501
# No feature data derived for cell at: LT0013_38, 42, 75, 1258, 381
# No feature data derived for cell at: LT0013_38, 42, 75, 818, 594
# No feature data derived for cell at: LT0013_38, 42, 95, 1261, 364
# No feature data derived for cell at: LT0013_38, 42, 95, 1308, 407
# No feature data derived for cell at: LT0013_42, 107, 76, 1053, 573
# No feature data derived for cell at: LT0013_42, 107, 76, 1312, 216
# No feature data derived for cell at: LT0013_42, 107, 76, 278, 715
# No feature data derived for cell at: LT0013_42, 107, 76, 607, 242
# No feature data derived for cell at: LT0014_12, 159, 70, 1265, 866
# No feature data derived for cell at: LT0017_19, 365, 83, 734, 253
# No feature data derived for cell at: LT0017_19, 365, 83, 767, 833
# No feature data derived for cell at: LT0017_19, 365, 93, 744, 259
# No feature data derived for cell at: LT0017_19, 365, 93, 797, 133
# No feature data derived for cell at: LT0017_19, 365, 93, 783, 940
# No feature data derived for cell at: LT0017_19, 365, 93, 868, 195
# No feature data derived for cell at: LT0019_06, 140, 70, 361, 879
# No feature data derived for cell at: LT0023_04, 5, 64, 696, 482
# No feature data derived for cell at: LT0023_04, 5, 87, 892, 597
# No feature data derived for cell at: LT0026_22, 258, 67, 1050, 779
# No feature data derived for cell at: LT0026_22, 258, 85, 870, 710
# No feature data derived for cell at: LT0027_44, 292, 88, 406, 102
# No feature data derived for cell at: LT0027_44, 30, 58, 205, 586
# No feature data derived for cell at: LT0027_44, 30, 74, 213, 627
# No feature data derived for cell at: LT0027_44, 30, 74, 802, 388
# No feature data derived for cell at: LT0027_44, 30, 86, 958, 286
# No feature data derived for cell at: LT0027_44, 30, 86, 82, 954
# No feature data derived for cell at: LT0027_44, 30, 86, 733, 690
# No feature data derived for cell at: LT0027_44, 30, 86, 200, 654
# No feature data derived for cell at: LT0027_44, 30, 86, 686, 601
# No feature data derived for cell at: LT0027_44, 30, 86, 232, 234
# No feature data derived for cell at: LT0027_44, 30, 86, 905, 338
# No feature data derived for cell at: LT0027_44, 30, 95, 897, 400
# No feature data derived for cell at: LT0027_44, 30, 95, 202, 657
# No feature data derived for cell at: LT0027_44, 30, 95, 735, 692
# No feature data derived for cell at: LT0027_44, 30, 95, 254, 431
# No feature data derived for cell at: LT0027_44, 30, 95, 755, 178
# No feature data derived for cell at: LT0027_44, 30, 95, 696, 601
# No feature data derived for cell at: LT0039_45, 281, 26, 1126, 558
# No feature data derived for cell at: LT0042_10, 144, 36, 230, 448
# No feature data derived for cell at: LT0042_10, 144, 88, 224, 890
# No feature data derived for cell at: LT0043_48, 166, 47, 276, 266
# No feature data derived for cell at: LT0043_48, 166, 55, 656, 255
# No feature data derived for cell at: LT0043_48, 166, 55, 438, 375
# No feature data derived for cell at: LT0043_48, 166, 56, 288, 310
# No feature data derived for cell at: LT0043_48, 166, 56, 338, 921
# No feature data derived for cell at: LT0043_48, 166, 74, 473, 337
# No feature data derived for cell at: LT0043_48, 166, 79, 475, 338
# No feature data derived for cell at: LT0043_48, 166, 79, 469, 602
# No feature data derived for cell at: LT0043_48, 166, 79, 795, 743
# No feature data derived for cell at: LT0043_48, 166, 79, 71, 678
# No feature data derived for cell at: LT0043_48, 166, 84, 472, 604
# No feature data derived for cell at: LT0043_48, 166, 84, 793, 745
# No feature data derived for cell at: LT0044_36, 249, 46, 146, 247
# No feature data derived for cell at: LT0046_19, 356, 92, 485, 196
# No feature data derived for cell at: LT0047_27, 140, 84, 132, 794
# No feature data derived for cell at: LT0065_04, 20, 57, 787, 473
# No feature data derived for cell at: LT0065_04, 20, 92, 1017, 824
# No feature data derived for cell at: LT0065_04, 20, 92, 765, 494
# No feature data derived for cell at: LT0065_06, 54, 93, 1002, 157
# No feature data derived for cell at: LT0067_02, 99, 77, 604, 686
# No feature data derived for cell at: LT0067_02, 99, 77, 775, 424
# No feature data derived for cell at: LT0067_02, 99, 92, 602, 690
# No feature data derived for cell at: LT0067_02, 99, 92, 265, 114
# No feature data derived for cell at: LT0084_46, 3, 46, 982, 454
# No feature data derived for cell at: LT0084_46, 3, 56, 783, 770
# No feature data derived for cell at: LT0084_46, 3, 56, 99, 390
# No feature data derived for cell at: LT0084_46, 3, 80, 1043, 538
# No feature data derived for cell at: LT0084_46, 3, 80, 380, 30
# No feature data derived for cell at: LT0084_46, 3, 80, 151, 247
# No feature data derived for cell at: LT0084_46, 3, 80, 183, 320
# No feature data derived for cell at: LT0084_46, 3, 91, 379, 137
# No feature data derived for cell at: LT0084_46, 3, 91, 918, 349
# No feature data derived for cell at: LT0084_46, 3, 91, 160, 144
# No feature data derived for cell at: LT0084_46, 3, 91, 789, 639
# No feature data derived for cell at: LT0089_01, 175, 39, 1133, 894
# No feature data derived for cell at: LT0089_01, 175, 39, 1121, 604
# No feature data derived for cell at: LT0089_01, 175, 44, 339, 34
# No feature data derived for cell at: LT0089_01, 175, 60, 772, 880
# No feature data derived for cell at: LT0089_01, 175, 71, 763, 875
# No feature data derived for cell at: LT0089_01, 175, 71, 393, 574
# No feature data derived for cell at: LT0089_01, 175, 93, 164, 438
# No feature data derived for cell at: LT0089_01, 175, 93, 276, 399
# No feature data derived for cell at: LT0089_01, 175, 93, 1027, 766
# No feature data derived for cell at: LT0093_13, 147, 69, 290, 228
# No feature data derived for cell at: LT0093_17, 114, 88, 794, 750
# No feature data derived for cell at: LT0093_17, 114, 88, 747, 391
# No feature data derived for cell at: LT0093_17, 114, 88, 603, 696
# No feature data derived for cell at: LT0093_17, 114, 88, 137, 718
# No feature data derived for cell at: LT0094_04, 319, 66, 1088, 939
# No feature data derived for cell at: LT0098_13, 21, 27, 627, 377
# No feature data derived for cell at: LT0098_13, 21, 77, 379, 655
# No feature data derived for cell at: LT0100_03, 93, 37, 581, 212
# No feature data derived for cell at: LT0100_03, 93, 37, 1311, 693
# No feature data derived for cell at: LT0100_03, 93, 56, 118, 521
# No feature data derived for cell at: LT0100_03, 93, 84, 1034, 629
# No feature data derived for cell at: LT0101_01, 277, 66, 976, 460
# No feature data derived for cell at: LT0132_31, 53, 51, 203, 201
# No feature data derived for cell at: LT0132_31, 53, 75, 498, 160
# No feature data derived for cell at: LT0132_31, 53, 75, 183, 217
# No feature data derived for cell at: LT0157_04, 5, 61, 515, 291
# No feature data derived for cell at: LT0157_04, 5, 78, 938, 351
# No feature data derived for cell at: LT0602_04, 59, 49, 363, 951
# No feature data derived for cell at: LT0602_04, 59, 49, 318, 907
# No feature data derived for cell at: LT0013_38, 42, 47, 1115, 361
# No feature data derived for cell at: LT0013_38, 42, 47, 987, 204
# No feature data derived for cell at: LT0013_38, 42, 47, 1052, 800
# No feature data derived for cell at: LT0013_38, 42, 47, 586, 882
# No feature data derived for cell at: LT0013_38, 42, 47, 326, 104
# No feature data derived for cell at: LT0013_38, 42, 47, 582, 299
# No feature data derived for cell at: LT0013_38, 42, 47, 262, 879
# No feature data derived for cell at: LT0013_38, 42, 75, 755, 949
# No feature data derived for cell at: LT0013_38, 42, 75, 382, 877
# No feature data derived for cell at: LT0013_38, 42, 75, 1239, 258
# No feature data derived for cell at: LT0013_38, 42, 75, 390, 417
# No feature data derived for cell at: LT0013_38, 42, 75, 208, 400
# No feature data derived for cell at: LT0013_38, 42, 75, 1296, 879
# No feature data derived for cell at: LT0013_38, 42, 95, 1180, 341
# No feature data derived for cell at: LT0013_38, 42, 95, 188, 407
# No feature data derived for cell at: LT0013_38, 42, 95, 922, 158
# No feature data derived for cell at: LT0013_38, 42, 95, 260, 380
# No feature data derived for cell at: LT0013_42, 107, 23, 407, 590
# No feature data derived for cell at: LT0013_42, 107, 28, 177, 764
# No feature data derived for cell at: LT0013_42, 107, 28, 111, 995
# No feature data derived for cell at: LT0013_42, 107, 52, 73, 295
# No feature data derived for cell at: LT0013_42, 107, 52, 410, 588
# No feature data derived for cell at: LT0013_42, 107, 52, 283, 77
# No feature data derived for cell at: LT0013_42, 107, 76, 1271, 473
# No feature data derived for cell at: LT0017_19, 365, 65, 1048, 464
# No feature data derived for cell at: LT0017_19, 365, 65, 197, 470
# No feature data derived for cell at: LT0017_19, 365, 65, 129, 355
# No feature data derived for cell at: LT0017_19, 365, 65, 712, 139
# No feature data derived for cell at: LT0017_19, 365, 65, 593, 53
# No feature data derived for cell at: LT0017_19, 365, 65, 494, 732
# No feature data derived for cell at: LT0017_19, 365, 65, 666, 356
# No feature data derived for cell at: LT0017_19, 365, 83, 588, 44
# No feature data derived for cell at: LT0017_19, 365, 83, 122, 490
# No feature data derived for cell at: LT0017_19, 365, 83, 1048, 466
# No feature data derived for cell at: LT0017_19, 365, 83, 718, 123
# No feature data derived for cell at: LT0017_19, 365, 83, 188, 748
# No feature data derived for cell at: LT0017_19, 365, 93, 586, 44
# No feature data derived for cell at: LT0017_19, 365, 93, 1047, 467
# No feature data derived for cell at: LT0023_04, 5, 30, 664, 319
# No feature data derived for cell at: LT0023_04, 5, 30, 73, 235
# No feature data derived for cell at: LT0023_04, 5, 87, 844, 949
# No feature data derived for cell at: LT0023_04, 5, 87, 525, 981
# No feature data derived for cell at: LT0026_22, 258, 37, 486, 939
# No feature data derived for cell at: LT0026_22, 258, 37, 520, 757
# No feature data derived for cell at: LT0026_22, 258, 37, 621, 295
# No feature data derived for cell at: LT0026_22, 258, 37, 1074, 595
# No feature data derived for cell at: LT0026_22, 258, 37, 891, 391
# No feature data derived for cell at: LT0026_22, 258, 37, 877, 522
# No feature data derived for cell at: LT0026_22, 258, 67, 1105, 728
# No feature data derived for cell at: LT0026_22, 258, 67, 493, 917
# No feature data derived for cell at: LT0026_22, 258, 67, 620, 300
# No feature data derived for cell at: LT0026_22, 258, 85, 942, 669
# No feature data derived for cell at: LT0026_22, 258, 85, 665, 476
# No feature data derived for cell at: LT0026_22, 258, 95, 658, 470
# No feature data derived for cell at: LT0026_22, 258, 95, 939, 674
# No feature data derived for cell at: LT0026_22, 258, 95, 751, 491
# No feature data derived for cell at: LT0026_22, 258, 95, 995, 695
# No feature data derived for cell at: LT0026_22, 258, 95, 494, 914
# No feature data derived for cell at: LT0027_44, 30, 58, 253, 234
# No feature data derived for cell at: LT0027_44, 30, 58, 1205, 809
# No feature data derived for cell at: LT0027_44, 30, 95, 248, 191
# No feature data derived for cell at: LT0028_14, 129, 17, 1134, 426
# No feature data derived for cell at: LT0028_14, 129, 55, 705, 97
# No feature data derived for cell at: LT0028_14, 129, 66, 1103, 458
# No feature data derived for cell at: LT0028_14, 129, 66, 566, 388
# No feature data derived for cell at: LT0028_14, 129, 66, 1321, 323
# No feature data derived for cell at: LT0028_14, 129, 66, 1210, 189
# No feature data derived for cell at: LT0028_14, 129, 91, 1170, 825
# No feature data derived for cell at: LT0028_14, 129, 91, 914, 666
# No feature data derived for cell at: LT0028_14, 129, 91, 585, 271
# No feature data derived for cell at: LT0028_14, 129, 91, 789, 144
# No feature data derived for cell at: LT0028_14, 129, 91, 594, 333
# No feature data derived for cell at: LT0028_14, 129, 91, 1059, 96
# No feature data derived for cell at: LT0028_14, 129, 91, 1132, 777
# No feature data derived for cell at: LT0038_27, 250, 8, 291, 799
# No feature data derived for cell at: LT0042_10, 144, 50, 579, 635
# No feature data derived for cell at: LT0043_48, 166, 36, 61, 667
# No feature data derived for cell at: LT0043_48, 166, 36, 498, 593
# No feature data derived for cell at: LT0043_48, 166, 36, 822, 721
# No feature data derived for cell at: LT0043_48, 166, 55, 997, 510
# No feature data derived for cell at: LT0046_19, 356, 57, 351, 64
# No feature data derived for cell at: LT0046_19, 356, 57, 676, 451
# No feature data derived for cell at: LT0046_19, 356, 57, 628, 513
# No feature data derived for cell at: LT0046_19, 356, 57, 625, 109
# No feature data derived for cell at: LT0046_19, 356, 57, 534, 127
# No feature data derived for cell at: LT0046_19, 356, 57, 533, 82
# No feature data derived for cell at: LT0046_19, 356, 67, 627, 435
# No feature data derived for cell at: LT0046_19, 356, 67, 772, 433
# No feature data derived for cell at: LT0046_19, 356, 67, 1089, 427
# No feature data derived for cell at: LT0046_19, 356, 67, 674, 449
# No feature data derived for cell at: LT0046_19, 356, 67, 622, 511
# No feature data derived for cell at: LT0046_19, 356, 67, 391, 141
# No feature data derived for cell at: LT0046_19, 356, 67, 807, 190
# No feature data derived for cell at: LT0046_19, 356, 67, 298, 497
# No feature data derived for cell at: LT0046_19, 356, 67, 353, 66
# No feature data derived for cell at: LT0046_19, 356, 67, 647, 600
# No feature data derived for cell at: LT0047_27, 140, 68, 115, 855
# No feature data derived for cell at: LT0047_27, 140, 75, 558, 400
# No feature data derived for cell at: LT0048_13, 69, 15, 337, 738
# No feature data derived for cell at: LT0065_04, 20, 49, 226, 289
# No feature data derived for cell at: LT0065_04, 20, 49, 579, 875
# No feature data derived for cell at: LT0065_04, 20, 57, 581, 873
# No feature data derived for cell at: LT0065_04, 20, 57, 1006, 788
# No feature data derived for cell at: LT0065_04, 20, 72, 300, 559
# No feature data derived for cell at: LT0065_04, 20, 72, 544, 875
# No feature data derived for cell at: LT0067_02, 99, 19, 549, 770
# No feature data derived for cell at: LT0067_02, 99, 19, 292, 978
# No feature data derived for cell at: LT0067_02, 99, 19, 1148, 815
# No feature data derived for cell at: LT0067_02, 99, 37, 132, 568
# No feature data derived for cell at: LT0067_02, 99, 37, 64, 818
# No feature data derived for cell at: LT0067_02, 99, 37, 264, 947
# No feature data derived for cell at: LT0067_02, 99, 37, 24, 809
# No feature data derived for cell at: LT0067_02, 99, 37, 271, 132
# No feature data derived for cell at: LT0067_02, 99, 37, 1130, 388
# No feature data derived for cell at: LT0067_02, 99, 37, 617, 848
# No feature data derived for cell at: LT0067_02, 99, 37, 1148, 869
# No feature data derived for cell at: LT0067_02, 99, 37, 722, 996
# No feature data derived for cell at: LT0067_02, 99, 37, 549, 746
# No feature data derived for cell at: LT0067_02, 99, 37, 207, 147
# No feature data derived for cell at: LT0067_02, 99, 37, 1159, 553
# No feature data derived for cell at: LT0067_02, 99, 37, 573, 34
# No feature data derived for cell at: LT0067_02, 99, 37, 1265, 185
# No feature data derived for cell at: LT0067_02, 99, 37, 1148, 818
# No feature data derived for cell at: LT0067_02, 99, 37, 739, 211
# No feature data derived for cell at: LT0067_02, 99, 37, 741, 802
# No feature data derived for cell at: LT0084_46, 3, 46, 1072, 823
# No feature data derived for cell at: LT0084_46, 3, 46, 694, 727
# No feature data derived for cell at: LT0084_46, 3, 46, 1004, 830
# No feature data derived for cell at: LT0084_46, 3, 46, 110, 121
# No feature data derived for cell at: LT0089_01, 175, 44, 1227, 348
# No feature data derived for cell at: LT0093_13, 147, 77, 741, 917
# No feature data derived for cell at: LT0093_13, 147, 77, 929, 123
# No feature data derived for cell at: LT0093_13, 147, 77, 842, 980
# No feature data derived for cell at: LT0100_03, 93, 37, 198, 140
# No feature data derived for cell at: LT0100_03, 93, 56, 1078, 704
# No feature data derived for cell at: LT0100_03, 93, 56, 133, 315
# No feature data derived for cell at: LT0100_03, 93, 84, 144, 711
# No feature data derived for cell at: LT0101_01, 277, 66, 1060, 655
# No feature data derived for cell at: LT0109_38, 381, 66, 774, 765
# No feature data derived for cell at: LT0109_38, 349, 69, 230, 109
# No feature data derived for cell at: LT0109_38, 349, 88, 1292, 961
# No feature data derived for cell at: LT0157_04, 5, 61, 858, 953
# No feature data derived for cell at: LT0602_04, 59, 49, 846, 491
# No feature data derived for cell at: LT0602_04, 59, 49, 900, 448
# No feature data derived for cell at: LT0602_04, 59, 49, 34, 542
# No feature data derived for cell at: LT0602_04, 59, 49, 245, 858
# No feature data derived for cell at: LT0602_04, 59, 49, 464, 938
# No feature data derived for cell at: LT0602_04, 59, 49, 100, 778
# No feature data derived for cell at: LT0602_04, 59, 49, 834, 390
# No feature data derived for cell at: LT0602_04, 59, 49, 344, 170
# No feature data derived for cell at: LT0602_04, 59, 49, 514, 256
# No feature data derived for cell at: LT0602_04, 59, 49, 379, 800
# No feature data derived for cell at: LT0602_04, 59, 49, 903, 89
# No feature data derived for cell at: LT0602_04, 59, 49, 87, 882
# No feature data derived for cell at: LT0602_04, 59, 49, 626, 408
# No feature data derived for cell at: LT0602_04, 59, 49, 442, 426
# No feature data derived for cell at: LT0602_04, 59, 49, 68, 496
# No feature data derived for cell at: LT0602_04, 59, 49, 568, 130
# No feature data derived for cell at: LT0602_04, 59, 49, 478, 891
# No feature data derived for cell at: LT0602_04, 59, 49, 813, 621
# No feature data derived for cell at: LT0602_04, 59, 49, 437, 602
# No feature data derived for cell at: LT0602_04, 59, 49, 827, 284
# No feature data derived for cell at: LT0602_04, 59, 49, 476, 783
# No feature data derived for cell at: LT0602_04, 59, 49, 670, 688
# No feature data derived for cell at: LT0602_04, 59, 49, 691, 770
# No feature data derived for cell at: LT0602_04, 59, 49, 146, 931
# No feature data derived for cell at: LT0602_04, 59, 49, 633, 97
# No feature data derived for cell at: LT0602_04, 59, 49, 631, 734
# No feature data derived for cell at: LT0602_04, 59, 49, 424, 708
# No feature data derived for cell at: LT0602_04, 59, 49, 96, 538
# No feature data derived for cell at: LT0602_04, 59, 49, 731, 637
# No feature data derived for cell at: LT0602_04, 59, 49, 168, 747
# No feature data derived for cell at: LT0043_48, 166, 36, 1207, 8
# No feature data derived for cell at: LT0026_22, 199, 13, 1154, 305
# No feature data derived for cell at: LT0027_44, 292, 65, 213, 234
# No feature data derived for cell at: LT0048_03, 254, 73, 695, 279
# No feature data derived for cell at: LT0100_03, 93, 37, 653, 173
# No feature data derived for cell at: LT0027_45, 48, 13, 1228, 1006
# No feature data derived for cell at: LT0027_45, 48, 13, 894, 465
# No feature data derived for cell at: LT0027_45, 48, 13, 1147, 864
# No feature data derived for cell at: LT0027_45, 48, 13, 937, 757
# No feature data derived for cell at: LT0027_45, 48, 13, 910, 905
# No feature data derived for cell at: LT0027_45, 48, 13, 1016, 363
# No feature data derived for cell at: LT0027_45, 84, 13, 553, 905
# No feature data derived for cell at: LT0027_45, 84, 13, 528, 849
# No feature data derived for cell at: LT0029_05, 60, 33, 553, 540
# No feature data derived for cell at: LT0029_05, 60, 33, 1028, 355
# No feature data derived for cell at: LT0029_05, 60, 33, 1071, 239
# No feature data derived for cell at: LT0029_05, 60, 33, 284, 232
# No feature data derived for cell at: LT0029_05, 60, 33, 985, 779
# No feature data derived for cell at: LT0029_05, 60, 33, 1109, 469
# No feature data derived for cell at: LT0078_05, 4, 33, 406, 988
# No feature data derived for cell at: LT0153_01, 13, 81, 1059, 539
# No feature data derived for cell at: LT0153_01, 13, 81, 295, 926
# No feature data derived for cell at: LT0153_01, 13, 81, 363, 454
# No feature data derived for cell at: LT0153_01, 13, 81, 603, 656
# No feature data derived for cell at: LT0153_01, 13, 81, 627, 429
# No feature data derived for cell at: LT0601_01, 217, 49, 693, 472
# Shape of labeled_cells: (2894, 1450)
